# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True, dtype=int)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','absolute_error'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[10,100]} 



grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/vivekanandhan/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   
# print classification report 
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}: 0.8743698364088219

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time
# 0        0.049243      0.008399         0.003057        0.000581  \
# 1        0.376142      0.008551         0.015073        0.000359
# 2        0.030263      0.000895         0.002487        0.000127
# 3        0.296016      0.014464         0.014815        0.000687
# 4        0.030690      0.001347         0.002390        0.000137
# 5        0.275573      0.006764         0.013920        0.000961
# 6        0.244874      0.002642         0.002609        0.000142
# 7        2.149561      0.392947         0.012614        0.002319
# 8        0.135748      0.006772         0.002654        0.000437
# 9        1.335653      0.084100         0.013261        0.000846
# 10       0.124923      0.003729         0.002345        0.000165
# 11       1.219854      0.088579         0.011020        0.001611
#
#    param_criterion param_max_features param_n_estimators
# 0    squared_error               auto                 10  \
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
#
#                                                params  split0_test_score
# 0   {'criterion': 'squared_error', 'max_features':...           0.795953  \
# 1   {'criterion': 'squared_error', 'max_features':...           0.802310
# 2   {'criterion': 'squared_error', 'max_features':...           0.784622
# 3   {'criterion': 'squared_error', 'max_features':...           0.812244
# 4   {'criterion': 'squared_error', 'max_features':...           0.796926
# 5   {'criterion': 'squared_error', 'max_features':...           0.806511
# 6   {'criterion': 'absolute_error', 'max_features'...           0.793372
# 7   {'criterion': 'absolute_error', 'max_features'...           0.787355
# 8   {'criterion': 'absolute_error', 'max_features'...           0.778227
# 9   {'criterion': 'absolute_error', 'max_features'...           0.806338
# 10  {'criterion': 'absolute_error', 'max_features'...           0.795932
# 11  {'criterion': 'absolute_error', 'max_features'...           0.808291
#
#     split1_test_score  split2_test_score  split3_test_score
# 0            0.716072           0.826004           0.770632  \
# 1            0.750575           0.836325           0.808984
# 2            0.750694           0.832444           0.798307
# 3            0.767174           0.835071           0.828467
# 4            0.765277           0.821328           0.810532
# 5            0.772888           0.842759           0.829284
# 6            0.741934           0.803955           0.804815
# 7            0.767677           0.817235           0.801882
# 8            0.751283           0.817855           0.799235
# 9            0.770249           0.837968           0.820516
# 10           0.754849           0.813646           0.814319
# 11           0.779284           0.839310           0.828180
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.759209         0.773574        0.036800               12
# 1            0.760634         0.791766        0.031809                5
# 2            0.726270         0.778467        0.036989               10
# 3            0.764029         0.801397        0.030173                3
# 4            0.753688         0.789550        0.025999                6
# 5            0.756906         0.801670        0.032578                2
# 6            0.746776         0.778170        0.027945               11
# 7            0.758585         0.786547        0.021520                8
# 8            0.763825         0.782085        0.023961                9
# 9            0.758471         0.798708        0.030014                4
# 10           0.767578         0.789265        0.024172                7
# 11           0.761957         0.803404        0.029074                1

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:45
# BMI:1
# Children:1
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[47863.7917507]
# [CV 5/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=auto, n_estimators=100;, score=0.751 total time=   0.4s
# [CV 3/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.821 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.811 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=0.747 total time=   0.3s
# [CV 1/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=0.787 total time=   2.5s
# [CV 1/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=auto, n_estimators=10;, score=0.796 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=auto, n_estimators=100;, score=0.809 total time=   0.4s
# [CV 4/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.829 total time=   0.3s
# [CV 5/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.757 total time=   0.3s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.821 total time=   1.3s
# [CV 2/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.779 total time=   1.3s
# [CV 3/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=auto, n_estimators=100;, score=0.836 total time=   0.4s
# [CV 2/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.773 total time=   0.3s
# [CV 3/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.843 total time=   0.3s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.770 total time=   1.3s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.838 total time=   1.4s
# [CV 2/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=auto, n_estimators=100;, score=0.802 total time=   0.4s
# [CV 1/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.797 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.765 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=0.804 total time=   0.2s
# [CV 4/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=0.805 total time=   0.2s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.764 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.806 total time=   1.4s
# [CV 3/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.839 total time=   1.3s
# [CV 4/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=auto, n_estimators=10;, score=0.826 total time=   0.1s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.751 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.726 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.828 total time=   0.3s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.764 total time=   0.3s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.778 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.751 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.758 total time=   1.5s
# [CV 4/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.828 total time=   1.2s
# [CV 3/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=auto, n_estimators=10;, score=0.771 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=auto, n_estimators=100;, score=0.761 total time=   0.4s
# [CV 1/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=0.793 total time=   0.2s
# [CV 2/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=0.742 total time=   0.2s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.818 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.799 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.796 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.755 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.814 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.814 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.768 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.808 total time=   1.3s
# [CV 5/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.762 total time=   1.1s
# [CV 2/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=auto, n_estimators=10;, score=0.716 total time=   0.1s
# [CV 1/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.785 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.798 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.767 total time=   0.3s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.835 total time=   0.3s
# [CV 2/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=0.768 total time=   2.4s
# [CV 3/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=0.817 total time=   1.8s
# [CV 1/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=auto, n_estimators=10;, score=0.759 total time=   0.1s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.832 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.812 total time=   0.3s
# [CV 5/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.754 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.807 total time=   0.3s
# [CV 4/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=0.802 total time=   2.6s
# [CV 5/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=0.759 total time=   1.6s
